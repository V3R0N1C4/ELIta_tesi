# %% [markdown]
# # Descrizione lessico ELIta
# Il lessico comprende 6905 elementi, tra parole ed emoji.
#
# Il set di dati contiene il:
# * 21% di aggettivi,
# * il 50% di nomi,
# * il 21% di verbi,
# * l'8% di parole che possono essere considerate sia aggettivi che nomi.
#
# Inoltre, è stato incluso un numero minore di avverbi, espressioni (ad esempio, "restare a bocca aperta" significa "guardare a bocca aperta") e interiezioni (ad esempio, "beh", "boh").
#
# La raccolta dei dati ha comportato un processo di annotazione che includeva sia l'associazione delle parole alle emozioni 8 di base (Plutchik), utilizzando una scala da:
# * "non associato" (0),
# * "debolmente associato" (0,25),
# * "moderatamente associato" (0,75),
# * "fortemente associato" (1),
#
# sia la valutazione degli elementi in base alle 3 dimensioni VAD (valenza, eccitazione e dominanza) utilizzando una scala da 1 a 9.
#
# Ognuna delle 6905 parole/emoji presenti nel lessico ha da un minimo di 5 a un massimo di 10 annotazioni (in media 5,13 annotazioni per parola).
#
# Il lessico è fornito in diverse versioni:
# * **RAW**, contiene **tutte** le annotazioni originali fatte dai partecipanti, senza filtri o aggregazioni.
# * **GOLDEN**, versione **pulita** della RAW. Sono state selezionate:
#     * le 5 annotazioni più simili tra loro per parola,
#     * più 1 riga generata automaticamente, "Golden Standard", calcolata dalla moda delle 5 annotazioni migliori.
# * **INTENSITY**, versione **aggregata continua**.\
# Ogni parola ha una record per emozione (sono state aggiunte: **amore**, media tra gioia e fiducia, e **neutrale**) e dimensione VAD (13 in totale), con la media delle annotazioni selezionate nella versione GOLDEN.
# * **BINARY**, versione **aggregata discreta**.\
# Converte le annotazioni continue della versione INTENSITY in valori binari (0 o 1) utilizzando una soglia di 0,5.

# %% [markdown]
# # Scelta della versione del lessico per la visualizzazione
# Per l'obbiettivo di visualizzazione del lessico ELIta con metodi distribuzionali, è stata scelta la versione **INTENSITY** del lessico.
#
# La ragione, per questa decisione, è che perché INTENSITY fornisce punteggi continui aggregati, necessari per calcolare le distanze semantiche precise tra le parole nello spazio vettoriale PCA/SVD.
#
# Il file è fornito in modo che ci sia una riga per ogni coppia parola-emozione, contenente la media delle annotazioni.\
#   Per l'analisi PCA, questo formato verrà trasformato in una matrice vettoriale dove ogni parola ha un unico vettore di punteggi per le 8 emozioni di base (Gioia, Tristezza, Rabbia, Disgusto, Paura, Fiducia, Sorpresa, Anticipazione) più le dimensioni VAD (Valenza, Attivazione, Dominanza) e le categorie aggiuntive (Amore, Neutrale).

# %% [markdown]
# # Caricamento e preparazione dati per l'utilizzo
# Importiamo il file ELIta_INTENSITY.txt come un DataFrame di pandas. \
# Dato che il file non presenta le intestazioni delle colonne, le definiamo qui manualmente.

# %%
import pandas as pd

intensityData = pd.read_csv("../ELIta_INTENSITY.txt", sep=',', header=None, names=['parola', 'emozione', 'valore'])
intensityData.head()
# Out:
#   parola   emozione  valore
# 0      ‼      gioia    0.71
# 1      ‼  tristezza    0.12
# 2      ‼     rabbia    0.67
# 3      ‼   disgusto    0.04
# 4      ‼      paura    0.17

# %% [markdown]
# Il DataFrame risultante ha tre colonne: `parola`, `emozione` e `valore`, dove:
#    - `parola` è la parola/emoji,
#    - `emozione` è l'emozione o dimensione associata,
#    - `valore` è il punteggio medio per quella parola-emozione.

# %% [markdown]
# ## Verifica integrità dati
# Controlliamo che i valori nelle colonne `parola` ed `emozione` non ci siano valori innaspettati.

# %%
unique_words = intensityData['parola'].nunique()
unique_emotions = intensityData['emozione'].nunique()
print(f"Numero di parole uniche: {unique_words}")
print(f"Numero di emozioni/dimensioni uniche: {unique_emotions}")
# Out:
# Numero di parole uniche: 6905
# Numero di emozioni/dimensioni uniche: 13

# %% [markdown]
# Controlliamo l'esistenza di valori mancanti nel DataFrame per verificare che tutto sia stato caricato correttamente.

# %%
total_nulls = intensityData.isnull().sum().sum()
print(f"Totale valori mancanti nel dataset: {total_nulls}")
# Out:
# Totale valori mancanti nel dataset: 0

# %% [markdown]
# ## Trasformazione del DataFrame in una matrice vettoriale
#
# Manipoliamo il del dataset in una matrice per avere una riga per ogni parola e una colonna per ogni emozione/dimensione.

# %%
pivotedData = intensityData.pivot(index='parola', columns='emozione', values='valore')
pivotedData
# Out:
# emozione      amore  aspettativa  attivazione  disgusto  dominanza  fiducia  \
# parola
# ????           0.08         0.17         7.00      0.17       4.33     0.04
# a_caso         0.04         0.21         5.00      0.08       3.00     0.04
# a_malincuore   0.00         0.12         5.50      0.21       3.67     0.00
# a_scanso_di    0.21         0.58         5.33      0.04       4.67     0.25
# abbagliante    0.32         0.62         7.00      0.00       6.50     0.17
# ...             ...          ...          ...       ...        ...      ...
# 🫤              0.02         0.25         4.67      0.25       5.00     0.00
# 🫥              0.00         0.04         4.00      0.08       4.00     0.00
# 🫦              0.02         0.42         3.33      0.00       4.83     0.04
# 🫰              0.43         0.29         4.50      0.12       6.00     0.29
# 🫶              0.73         0.58         7.00      0.00       6.00     0.67
#
# emozione      gioia  neutrale  paura  rabbia  sorpresa  tristezza  valenza
# parola
# ????           0.12       0.0   0.17    0.42      0.79       0.42     5.17
# a_caso         0.04       0.0   0.54    0.29      0.83       0.21     4.33
# a_malincuore   0.00       0.0   0.21    0.21      0.04       0.83     3.33
# a_scanso_di    0.17       0.0   0.17    0.42      0.21       0.25     5.00
# abbagliante    0.46       0.0   0.12    0.12      0.71       0.04     6.67
# ...             ...       ...    ...     ...       ...        ...      ...
# 🫤              0.04       0.0   0.08    0.12      0.17       0.29     4.67
# 🫥              0.00       0.0   0.04    0.04      0.04       0.21     3.67
# 🫦              0.00       0.0   0.00    0.00      0.50       0.00     4.67
# 🫰              0.58       0.0   0.12    0.17      0.38       0.29     6.17
# 🫶              0.79       0.0   0.00    0.00      0.42       0.00     7.50
#
# [6905 rows x 13 columns]

# %% [markdown]
# La matrice risultante ha:
# - **Righe**: 6905 (una per ogni parola/emoji)
# - **Colonne**: 13 (8 emozioni di base + 2 extra + 3 dimensioni VAD)
# - **Valori**: punteggi medi di intensità per ogni parola-emozione/dimensione.

# %% [markdown]
# ## Salvataggio della matrice vettoriale
# Salviamo la matrice vettoriale in un file CSV per utilizzi futuri.

# %%
pivotedData.to_csv("ELIta_INTENSITY_Matrix.csv")
print("Matrice vettoriale salvata come ELIta_INTENSITY_Matrix.csv")
# Out:
# Matrice vettoriale salvata come ELIta_INTENSITY_Matrix.csv

# %% [markdown]
# ---

# %% [markdown]
# # Visualizzazione tramite Riduzione Dimensionale (PCA e TruncatedSVD).
# La matrice a 13 dimensioni appena creata verrà schiacciata in 2 dimensioni per poterla meglio visualizzare in un piano 2D.  Cercando di perdere il meno possibile dell'informazione originale.
#
# Le due tecniche di riduzione dimensionale che verranno utilizzate sono:
# * **PCA (Principal Component Analysis)**: parte trovando la media di ogni dimensione, poi sposta tutti i punti in modo che la media coincida con l'origine degli assi. Solo a quel punto cerca gli assi lungo cui i punti sono più dispersi attorno a quel centro. PC1 è la direzione di massima varianza, PC2 la seconda, e così via, tutti perpendicolari tra loro.
# * **TruncatedSVD (Singular Value Decomposition)**: non cerca di centrare nulla. Prende direttamente gli assi lungo cui i punti hanno più "energia" — cioè massimizza la varianza totale rispetto all'origine, non rispetto alla media.
#
# Entrambi i metodi ci permetteranno di visualizzare le parole in uno spazio 2D, dove la vicinanza tra i punti riflette la somiglianza emotiva tra le parole.
#
# La differenza principale tra i due metodi riguarda la centratura dei dati: PCA sottrae la media prima di calcolare gli assi, TruncatedSVD no. Questo rende TruncatedSVD più adatto a matrici sparse come il lessico ELIta, dove i gli zero significano "nessuna associazione" e non andrebbero alterati dalla centratura.

# %% [markdown]
# ## Specifiche per la visualizzazione
# Questo è la procedura che utilizzaremo per applicare PCA, t-SNE e TruncatedSVD per l'analisi:
#
# 1. **Emozione/Dimensione**: per la visualizzazione delle "parole in base all'emozione", useremo:
#     - prima, solo le 8 emozioni di base di Plutchik.
#     - sucessivamente, aggiungere le 2 emozioni extra (amore e neutrale).
#     - poi, le 3 dimensioni VAD.
#     - ed infine, tutte le 13 feature insieme.
#
#
# 2. **Parole/emoji**: il lessico contiene sia parole che emoji. Inizialmente, per questa prima fase di visualizzane, non si erano separate le parole dalle emoji, ma nei grafici molte emoji non veniva ben gestite (non venivano visualizzate come emoji, ma come quadratini vuoti).
#
#    Per questo motivo, abbiamo deciso di separare le parole dalle emoji e fare due analisi distinte:
#     - In questo notebook analizzeremo le emoji.
#     - In `AnalisiParole.ipynb` verrànno visualizzate le parole seguendo la stessa pocedera di questo notebook.

# %% [markdown]
# ## Separazione dei Dati (Emoji vs Parole)

# %%
import emoji
import plotly.io as pio

pio.renderers.default = "notebook_connected"                                # per collab

def is_likely_emoji(text):
    return emoji.emoji_count(str(text)) > 0

pivotedData['is_emoji'] = [is_likely_emoji(x) for x in pivotedData.index]

df_only_emojis = pivotedData[pivotedData['is_emoji'] == True].copy()
df_only_words = pivotedData[pivotedData['is_emoji'] == False].copy()

print(f"Totale elementi: {len(pivotedData)}")
print(f"Numero di Emoji trovate: {len(df_only_emojis)}")
print(f"Numero di Parole testuali: {len(df_only_words)}")
# Out:
# Totale elementi: 6905
# Numero di Emoji trovate: 186
# Numero di Parole testuali: 6719

# %%
df_only_emojis.head()
# Out:
# emozione  amore  aspettativa  attivazione  disgusto  dominanza  fiducia  \
# parola
# ‼          0.35         0.17         6.67      0.04       5.17     0.00
# ⁉          0.11         0.21         7.67      0.04       5.50     0.04
# ☠          0.15         0.04         6.00      0.46       5.50     0.12
# ☹          0.02         0.12         5.83      0.08       3.50     0.04
# ☺          0.73         0.50         6.17      0.00       7.00     0.54
#
# emozione  gioia  neutrale  paura  rabbia  sorpresa  tristezza  valenza  \
# parola
# ‼          0.71       0.0   0.17    0.67      0.83       0.12     5.00
# ⁉          0.17       0.0   0.29    0.17      0.71       0.08     4.33
# ☠          0.17       0.0   0.67    0.54      0.17       0.58     3.83
# ☹          0.00       0.0   0.21    0.17      0.04       1.00     2.67
# ☺          0.92       0.0   0.00    0.00      0.62       0.00     7.33
#
# emozione  is_emoji
# parola
# ‼             True
# ⁉             True
# ☠             True
# ☹             True
# ☺             True

# %%
df_only_words.head()
# Out:
# emozione      amore  aspettativa  attivazione  disgusto  dominanza  fiducia  \
# parola
# ????           0.08         0.17         7.00      0.17       4.33     0.04
# a_caso         0.04         0.21         5.00      0.08       3.00     0.04
# a_malincuore   0.00         0.12         5.50      0.21       3.67     0.00
# a_scanso_di    0.21         0.58         5.33      0.04       4.67     0.25
# abbagliante    0.32         0.62         7.00      0.00       6.50     0.17
#
# emozione      gioia  neutrale  paura  rabbia  sorpresa  tristezza  valenza  \
# parola
# ????           0.12       0.0   0.17    0.42      0.79       0.42     5.17
# a_caso         0.04       0.0   0.54    0.29      0.83       0.21     4.33
# a_malincuore   0.00       0.0   0.21    0.21      0.04       0.83     3.33
# a_scanso_di    0.17       0.0   0.17    0.42      0.21       0.25     5.00
# abbagliante    0.46       0.0   0.12    0.12      0.71       0.04     6.67
#
# emozione      is_emoji
# parola
# ????             False
# a_caso           False
# a_malincuore     False
# a_scanso_di      False
# abbagliante      False

# %% [markdown]
# ## Visualizzazione delle Emoji (PCA)

# %% [markdown]
# ### Visualizzazione PCA per le 8 Emozioni di Base
# Il seguente codice esegue la PCA sulle emoji basandosi solo sulle 8 emozioni di base e crea un grafico con due visualizzazioni affiancate: una con le emoji come testo e l'altra con marker colorati.

# %%
from Fase1.emotion_config import EMOTION_COLORS, BASIC_EMOTIONS, ALL_EMOTIONS, VAD_FEATURES
from Fase1.pca_utils import perform_pca_analysis 
from Fase1.visualizer import plot_pca_emotions

dominant_basic = df_only_emojis[BASIC_EMOTIONS].fillna(0).idxmax(axis=1)
pca_basic = perform_pca_analysis(df_only_emojis, BASIC_EMOTIONS, dominant_basic)

fig1 = plot_pca_emotions(
    pca_data=pca_basic,
    colors_dict={k: v for k, v in EMOTION_COLORS.items() if k in BASIC_EMOTIONS},
    title="PCA: Distribuzione Emoji (8 Emozioni Base)"
)
fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="b1da297d-ed43-461b-8040-d5df5c65a250" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b1da297d-ed43-461b-8040-d5df5c65a250")) {                    Plotly.newPlot(                        "b1da297d-ed43-461b-8040-d5df5c65a250",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],
="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u ...

# %% [markdown]
# Possiamo notare che la nuvola gialla (**gioia**) è ben separata, con qualche sovrapposizione di verde chiaro (**fiducia**). Entrambe emozioni positive.
#
# **Paura** (verde scuro), **tristezza** (blu), **disgusto** (viola) e **rabbia** (rosso) formano un gruppo più compatto, con qualche sovrapposizione tra loro, ma ben separate da gioia e fiducia.
#
# A metà strada tra questi due gruppi, troviamo la **sorpresa** (azzurro) e l'**anticipazione** (arancione).

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 10 Emozioni (8 di base + 2 extra)

# %%
dominant_all = df_only_emojis[ALL_EMOTIONS].fillna(0).idxmax(axis=1)
pca_all = perform_pca_analysis(df_only_emojis, ALL_EMOTIONS, dominant_all)

fig2 = plot_pca_emotions(
    pca_data=pca_all,
    colors_dict=EMOTION_COLORS, # Usa tutti i colori
    title="PCA Emoji: Spazio a 10 Emozioni (+ Amore e Neutrale)"
)
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="5d987e5e-a715-4da8-b1e0-ca1495b964a1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5d987e5e-a715-4da8-b1e0-ca1495b964a1")) {                    Plotly.newPlot(                        "5d987e5e-a715-4da8-b1e0-ca1495b964a1",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f8","bdata":"0dmVMzdV7D\u002fPtSOdx2\u002fpP0BS2uGYS8o\u002f4IDtAUQcij9DFqVpkc7qP3Q9wetH9vA\u002fbGro5\u002fTMyb9NwICTWnvjP\u002fZCrLnBi\u002fA\u002f7YiD7boy5z8yOvkOvHPwP2AverTbgp2\u002fGEXQZOUYvz8BYfS0iErsPwCMx6\u002fpkI+\u002f7AJrmwUNtb880jX8SH3WP++orFXatuM\u002fkq5MFBdJ1T8xNfPf+23lPzOci\u002flpIe0\u002fkWEvMFn46z9SQU9BXl3UP8WbvkGDTes\u002fYr4+2ofS8z+PT8d2ifXkP0\u002fmUZoPRO8\u002fOkZSEAx08z9g9Gg\u002fr5aWP+HT2pTZqOI\u002f\u002fo7\u002fTg6T1j+DKeBMY5nnPyuglnhMLOY\u002ffRe2\u002fDok6T8UXp4v1w\u002faPx9ue9klE+k\u002ff0jir\u002frV5j9ox8tMEdfKP31SpVaWl+c\u002f5igN7GYo2D++ZwkC+BzYP6gMfUiAX9U\u002f4oRZ2YY08T+qDY\u002fMjCnwP+JY01FFHNQ\u002f6NhFQvGS8D\u002ftkFlzk9biPxIvasJKzNY\u002fnybjri0x4z9g2Vnz72vPPxMZn6e7+OY\u002fdt55tkCt07926aUBIurCv0y3nf8rHdc\u002fu8jmoYVh6z\u002f9hhfUDtDrPw701xQ5QNw\u002fiOzxcivZyz+wugq2QxOmPwC\u002f+9ag2t0\u002fMpI7M+Ol2T9RXcxgE0jjP\u002fdvQUCXO+Q\u002fUsiPxJCF3D8I6IRxhxDxPxtm0WlEIu0\u002f4UZk5jDl5D\u002fA54sEkfXwP4i0Fg7DTsk\u002fFUgLcQMn6z8="},"y":{"dtype":"f8","bdata":"9G+HxjVitj\u002fSPknmx\u002fLBv1iYfnsYYMq\u002fR4zEqHMQ2b9SyatGYS7LP0JA95K4Ls0\u002fb03olZzHzb\u002fi26puSurFv4VvBo9EB9Y\u002fiiGQ8w7Xxr9Gl7rSjRDDP8ZvklBIg92\u002fdFmir5lKzr\u002f2Kas0Wg3MP\u002fikkgyl6q4\u002fYMHkwpKq1r9gLMWUFVO6v7BHIcr4HrW\u002f1qY0IZm\u002f0r98GhbbrrXIv3HoDjjqeNQ\u002fHJg5FX43vD8wUqLsbyTEv4iWgDRttqC\u002ffjPDbOPRwD9GdiX\u002f2nfBP\u002fBCqBG0Spc\u002f\u002fiPN7iOAwD8o1pz6dyWoPxhZEJOlhqM\u002fhn5iEeNRxL8fqv8BvmbNvwDlAWH9t6C\u002f+HOQXl420r9cSIUwKb\u002fMv1hWXmJyZa6\u002f2Ik3wg1Hpb\u002frXUjAfBzgv8gMBEtf9a+\u002fGLrJBwW5y7\u002fyFTHZs4rMvzhLtOcOLbO\u002f7tkgSWlPxj++zN7\u002flWDCP7QdirdfUM+\u002f8HvkOk2ylj+oD6CvNzOxvxyYvKmXS9G\u002f7I3mAYtBsT8k7NwEPFC3P8rK9g6YTMY\u002fS2rMgPjk3b+s59dpSq63v9iPFyunbLu\u002fjGqaw1y\u002fuT+xdAcLNtfQv5FoIpBjsdi\u002fcGNCvxmowL9AiV1RvxzZv6BWJnEARsy\u002fmHn21YhL07+UQUhgLNjKvzA8r0Uhgpw\u002f6J8dHmBprT\u002f6Lg6Nzm3MPyLlhNR38sG\u002f6GP50jmGrj9A\u002f8hpMnmdvyCXqEqmXIQ\u002f4HLcRplzmr8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u00 ...

# %% [markdown]
# Aggiungendo le emozioni extra il grafico sembra rimanere abbastanza invariato.
# Questo perché **amore** è una media tra **gioia** e **fiducia**, quindi non può mai avere un valore più alto di entrambe, e non introduce informazione nuova rispetto a quelle già presenti. Mentre **neutrale** ha valore zero per ogni parola, quindi non aggiunge alcuna varianza e viene di fatto ignorato dalla PCA.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 3 Dimensioni VAD, senza standirdizzazione
#
# Senza standardizzazione, per vedere l'effetto delle scale originali. Le VAD (1-9) pesano molto di più delle emozioni (0-1), e si vede come i punti si distribuiscono guidati principalmente dai valori grezzi 1-9.

# %%
pca_vad = perform_pca_analysis(df_only_emojis, VAD_FEATURES, dominant_all, scale=False)

fig3 = plot_pca_emotions(
    pca_data=pca_vad,
    colors_dict=EMOTION_COLORS,
    title="PCA: Proiezione VAD (Valenza, Arousal, Dominance)",
    plot_loadings=True,
    feature_names=['Valenza', 'Attivazione', 'Dominanza']
)
fig3.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="8d86b4e8-2723-4e59-ac78-fee0477ae674" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8d86b4e8-2723-4e59-ac78-fee0477ae674")) {                    Plotly.newPlot(                        "8d86b4e8-2723-4e59-ac78-fee0477ae674",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],
="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u ...

# %% [markdown]
# Come possimo vedere nel grafico **Distribuzione con Marker** le VAD sono indicate da etichette che riprendono il nome della dimensione (Valenza, Attivazione, Dominanza).
#
# Le emoji con valenza maggiore si trovano a destra. La valenza indica quanto uno stimolo è percepito come positivo o negativo, quindi le emoji più positive (ad esempio, quelle associate alla gioia e alla fiducia) tendono a posizionarsi verso destra, mentre quelle più negative (ad esempio, quelle associate alla tristezza, rabbia, paura e disgusto) tendono a posizionarsi verso sinistra.
#
# Le emoji più attive in alto. L'attivazione indica quanto uno stimolo è percepito come energico o calmo.
#
# Quelle più dominanti in centro-destra. La dominanza misura il senso di controllo che l'individuo sente di avere sulla situazione scatenata dall'emozione, contrapposto alla sensazione di esserne sopraffatto.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 3 Dimensioni VAD, con standirdizzazione
# Con standardizzazione (z-score), tutte le feature vengono portate sulla stessa scala (media 0, deviazione standard 1).

# %%
pca_vad_scaled = perform_pca_analysis(df_only_emojis, VAD_FEATURES, dominant_all, scale=True)

fig4 = plot_pca_emotions(
    pca_data=pca_vad_scaled,
    colors_dict=EMOTION_COLORS,
    title="PCA: Proiezione VAD Standardizzata (Z-Score)",
    plot_loadings=True,
    feature_names=['Valenza', 'Attivazione', 'Dominanza']
)
fig4.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="ed23562f-0d1d-4dbb-82c5-49774f79e5c9" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ed23562f-0d1d-4dbb-82c5-49774f79e5c9")) {                    Plotly.newPlot(                        "ed23562f-0d1d-4dbb-82c5-49774f79e5c9",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f8","bdata":"xd+GNCW0AEAhdIt5yLjwP+RPAPZGI+0\u002fXZQ9y8w+7j+WKvRQmW3YP1+ZaIQzJfM\u002fNjL+Anyyrz8ljQlO4vbvPwrPw91FrPg\u002fE2Fj3gls4j+2l8XJKRvrP1O6DeFLRfY\u002f4mMLcp2J7T+o77uFkiz6P538a\u002f1t1\u002fA\u002fSrVGDe9d3j9hDpAh9k3lPwB\u002fA4aryuI\u002fGGw6HUrrAkCbBN6n1EjyPy9RcsJfAgdAulv0Exso\u002fT9edNkGPHjVP1oFgnPsHPw\u002fGgeXvQdBAkDhM0zs8yr2P8zPvKt+tfM\u002f\u002f7RvTHdk+D\u002fOF18Dh5nePzSa785bEfM\u002f\u002fyrQzDM37j+CYE\u002fvS+b9P8Jb80bzp\u002fM\u002fRqHyMnen+T9NiZwzQ1P1P2CU74P1rPs\u002frOiro38A7j+YyLfwIi7eP3MV\u002fFleH\u002fw\u002fBkOkeYZK9D+NGEpZDYT9PxGe22NB9Pg\u002fjRRirveM5T\u002fWMfzv2mf8P3ZvA0L5jqW\u002fjuezSYeb+z+t\u002fU6eYuXpP1ps+5U9+e8\u002fnOGRmznt8z8CTWMuMZfEv4UAOtIUTwFAxUMm+7\u002f58r+br8w0rLjPv9FBpfhMY9Y\u002fYUOSl\u002fx+\u002fT+bJvyDaSf3P6Zo1Qzb5cS\u002fVIWes1QCzz8IulfX5gHjP+e5eDBdtvk\u002f\u002fcyKpSWT6j8OBEpxqAP5P5v9pOBngfQ\u002fm6Ul8fo15D+dKiFgcP0NQGWypC+70\u002fM\u002fEsl5nKJBBkDrmctNlKvyP+GimzAyOOY\u002f90Z+QHBy+j8="},"y":{"dtype":"f8","bdata":"xhNi8m1z3T+bOuPYptm3PzGpDXrCvdO\u002fEXDpUjSU5T+slbXQwU3nPz2KgTe99cs\u002fcNpAitY31r\u002fZ+rbVJYbzvyrwgb0FIt6\u002fXpOqdpPKA8ArYnkBABLfvxgBj6\u002f3pvu\u002fnKPBthQbx79dksaL5SqJP+21CP+fkda\u002fT2h5biCX+b8mrXf76SjYP9MYo5anr8w\u002fkwNKDQzcsT8My2J7eirsv1cj8LUt9eQ\u002fjo20GQ5R5D9ax9S1vrniv5ZcaRml4fK\u002fJSTi60OX0b8uE9axvoXsP2JT\u002fzSl3vM\u002fn9IcJ7jW378qTiTs59biv1SWbBZ3rOM\u002fIC9Ks6jc3j+d3P4bKJrgv51Q\u002fQv4RdC\u002fkiWqer6L6r+tKvH4QBnoP7rjl4S3HsK\u002fNciED5CR678kygx8zi+pPwmUX7p8FOC\u002f1O1FtpOY2L\u002fzzI8NjRHwP9SPPxqlSve\u002ftF\u002fVByyE6r\u002fpfeJZCqLfP5\u002fzfOuGP\u002fO\u002fdz0RL+YV879aSayuFSHWv4YpEaCYNua\u002fQW2+utAq0b+C89IG0ueTP1kPtqVvAvQ\u002fO5hTRehNBsCZPIhLOmfuvxRVrZ8Vr7K\u002fbujEtB8k5T+lPgODHeTlP2A5PfofueS\u002fFW1Lz1Nx8L9bVeZ6\u002fpXpv4NzkdhpLsc\u002fm5OLePJ61L+tLq\u002f865X4P+HyvBm6U+I\u002fuHL4iyFy+D\u002fH5i7ZFJ3yP6dDR0WIo72\u002fana5lGes1r\u002f9jeTq5vvav8ld29k0iu6\u002feTDMRwB99T8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f ...

# %% [markdown]
# Applicando la standardizzazione, vediamo che le etichette di Dominanza e Valenza sono quasi sovrapposte, indicando che queste due dimensioni sono fortemente correlate tra loro. L'Attivazione invece è più perpendicolare, suggerendo che è una dimensione più indipendente rispetto alle altre due.
#
# Per il resto, la distribuzione delle emoji rimane simile a quella senza standardizzazione.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA VAD 3D

# %%
from visualizer import plot_pca_3d

pca_vad_3d = perform_pca_analysis(
    df=df_only_emojis, 
    features_columns=VAD_FEATURES, 
    dominant_emotions=dominant_all, 
    scale=True,        
    n_components=3     
)

fig_3d = plot_pca_3d(
    pca_data=pca_vad_3d,
    colors_dict=EMOTION_COLORS,
    title="Spazio Emotivo 3D (Derivato da VAD)"
)

fig_3d.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="22c6c478-e5b3-4e6b-8f7c-3347d42dbe0a" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("22c6c478-e5b3-4e6b-8f7c-3347d42dbe0a")) {                    Plotly.newPlot(                        "22c6c478-e5b3-4e6b-8f7c-3347d42dbe0a",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u
89IG0ueTP1kPtqVvAvQ\u002fO5hTRehNBsCZPIhLOmfuvxRVrZ8Vr7K\u002fbujEtB8k5T+lPgODHeTlP2A5PfofueS\u002fFW1Lz1Nx8L9bVeZ6\u002fpXpv4NzkdhpLsc\u002fm5OLePJ61L+tLq\u002f865X4P+HyvBm6U+I\u002fuHL4iyFy+D\u002fH5i7ZFJ3yP6dDR0WIo72\u002fana5lGes1r\u002f9jeTq5vvav8ld29k0iu6\u002feTDMRwB99T8="},"z":{"dtype":"f8","bdata":"w10gHhpb3D8lih21kgnwvx6sjQNaU+M\u002 ...

# %% [markdown]
# Visto che le VAD sono tre, si è provato a visualizzare le emoji in uno spazio 3D, per vedere se emerge qualche struttura più chiara.
#
# Da questa visualizzazione 3D non sembra emergere una struttura troppo differente rispetto alla visualizzazione 2D. Le emoji continuano a formare un gruppo abbastanza compatto, con una distribuzione simile a quella vista nella PCA 2D.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pca_obj = pca_vad_3d['pca_object']
components = pca_obj.components_

loadings_df = pd.DataFrame(
    components,
    columns=['Valenza', 'Attivazione', 'Dominanza'],
    index=['PC1', 'PC2', 'PC3']
)

plt.figure(figsize=(8, 4))
sns.heatmap(loadings_df, annot=True, cmap='RdBu', center=0, fmt='.2f', vmin=-1, vmax=1)
plt.title("Di cosa sono fatti gli assi PC? (Correlazione Features-Componenti)")
plt.show()

print(loadings_df)
# Out:
#       Valenza  Attivazione  Dominanza
# PC1  0.691202     0.190445   0.697116
# PC2 -0.166901     0.980640  -0.102415
# PC3 -0.703125    -0.045560   0.709606

# %% [markdown]
# L'heatmap mostra la correlazione tra le dimensioni VAD e le componenti principali.
# - **PC1** è fortemente correlata con Valenza e Dominanza, suggerendo che questa componente rappresenta una dimensione di "positività/controllo".
# - **PC2** è fortemente correlata con Attivazione, indicando che questa componente rappresenta una dimensione di "energia/attività".
# - **PC3** è positivamente correlata con Dominanza e negativamente con Valenza ovvero emoji percepite come dominanti ma non necessariamente positive.

# %% [markdown]
# ### Visualizzazione PCA per tutte le 13 Feature

# %%
hybrid_features = ALL_EMOTIONS + VAD_FEATURES

pca_hybrid = perform_pca_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all, 
    scale=True
)

fig5 = plot_pca_emotions(
    pca_data=pca_hybrid,
    colors_dict=EMOTION_COLORS,
    title="PCA Ibrida: Relazione tra Emozioni Discrete e Dimensioni VAD",
    plot_loadings=True,
    feature_names=hybrid_features 
)

fig5.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="07947a6b-72f9-436a-a387-47fdd4b56a3b" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("07947a6b-72f9-436a-a387-47fdd4b56a3b")) {                    Plotly.newPlot(                        "07947a6b-72f9-436a-a387-47fdd4b56a3b",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],
="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e", ...

# %% [markdown]
# In questa visualizzazione ibrida, vediamo come le emozioni discrete e le dimensioni VAD interagiscono nello spazio PCA.
#
# Le etichette di **fiducia**, **gioia**, **amore**, **dominanza** e **valenza** sono molto vicine tra loro, in alcuni casi anche sovrapposte, indicando che queste dimensioni sono fortemente correlate e rappresentano un cluster di emoji positive e dominanti.
#
# L'etichetta di neutrale è perfettamente sovrapposta a zero, quindi non è visibile, e non contribuisce alla varianza, come ci aspettavamo.
#
# Anche le emozioni negative **rabbia**, **paura**, e disgusto tendono a raggrupparsi insieme, ma sono più distanti dalle dimensioni VAD, suggerendo che queste emozioni discrete catturano aspetti specifici che non sono completamente spiegati dalle dimensioni VAD.

# %% [markdown]
# ## Visualizzazione delle Emoji (metodi diversi dalla PCA)
# Oltre alla PCA, le altre due tecniche di riduzione dimensionale che useremo sono:
# * **t-SNE (t-distributed Stochastic Neighbor Embedding)**: tecnica non lineare che separa bene i cluster, ma non garantisce che le distanze globali siano significative. Ottimo per visualizzare gruppi di emoji simili. Ma due cluster lontani nel grafico t-SNE non sono necessariamente più diversi di due cluster vicini.
# * **TruncatedSVD (Singular Value Decomposition)**: simile alla PCA, ma più efficiente per matrici sparse e non richiede la centratura dei dati.

# %% [markdown]
# ### t-SNE
#
# Questa visualizzazione è utile per vedere se esistono cluster naturali tra le emoji, ma non puoi interpretare le distanze tra i gruppi.

# %%
from Fase1.pca_utils import perform_tsne_analysis

hybrid_features = ALL_EMOTIONS + VAD_FEATURES

tsne_data = perform_tsne_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all, 
    perplexity=25,  # (5 - 50), max valore di perplexity = numero emoji - 1
    scale=True      # t-SNE funziona meglio con dati scalati, visto che hybrid_features hanno scale diverse
)

fig_tsne = plot_pca_emotions(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE: Clustering non-lineare delle Emoji (13 Feature)",
    plot_loadings=False # Non hanno senso vettori in t-SNE
)

fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9e9098df-3fc4-4c86-bdcd-6871ab0ebcf2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9e9098df-3fc4-4c86-bdcd-6871ab0ebcf2")) {                    Plotly.newPlot(                        "9e9098df-3fc4-4c86-bdcd-6871ab0ebcf2",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f4","bdata":"8+StQPNrqkCxJvc\u002fPxoTPzsN0EBHx+NAU3zbv7d1eT+Yce5AV\u002f5zPubUwEB0KNO\u002fDfj3PzgBhkCSxGtAsMy0vzr7jEBBbZJAuDtnQFo++j8yThNBLUbXQBa4gT+KB25ASxbRQAvm+UAMWv9AcMO9QOqIf0Dw\u002f\u002fFARcyGQDcxZEC6jWtAHrgdQEtKjEDhUVdAgkm9PylH6z7QAoZAdTMcQBqfskD1tHZAyQ+nQGjC6EA109+9VLyAQC+fY0BvIxlAtiDcP\u002fPiF0DOzaNAtkuLwKyaDb8ji3BAdYbpQE8VtECd1cE+fgesQAW1pb57q3FA06YEQGgjqEDJbuJAy1gDQcfbG0H9YKtA02XuP8oEqEAB8ZBAu8XtQA=="},"y":{"dtype":"f4","bdata":"8W9wQbvfRkGQ789AlxVxQP5XXUEhs4dBQU4kvjufKEGhmJFB0pk2QcvMhkHb0odAkVagQN7db0HPz3K8WryiQD56B0EhUSNB9rLHQD+AOEGf8YhBDsRyQaHXDEF1KINBYv+PQX3YS0E1u2dBRHaOQWQvebww8jlBG9PzQOXuSkEetDdBY0U\u002fQcvw1UDcA1xB7kFOQfLfvUCReE9B5Oj9QLfL9kBWYodAWkiMQXnHf0EAFvBAaeGIQXXHMEH3EL9AukZYQYtsrT+++WlBq0SrPmjGor8MqwxB0ZR1QStlOUHoAwNBaOFBQM0OpEC4s9xAZEwGQWUt20BAqURBZ0QcQSoog0EPDU1ByRpzQQLEhkHBQrk+aiJlQQ=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","marker":{"color":"#FDD835","line":{"color":"white","width":1.5},"opacity":0.8,"size":12},"mode":"markers","name":"gioia","showlegend":true,"x":{"dtype":"f4","bdata":"8+StQPNrqkCxJvc\u002fPxoTPzsN0EBHx+NAU3zbv7d1eT+Yce5AV\u002f5zPubUwEB0KNO\u002fDfj3PzgBhkCSxGtAsMy0vzr7jEBBbZJAuDtnQFo++j8yThNBLUbXQBa4gT+KB25ASxbRQAvm+UAMWv9AcMO9QOqIf0Dw\u002f\u002fFARcyGQDcxZEC6jWtAHrgdQEtKjEDhUVdAgkm9PylH6z7QAoZAdTMcQBqfskD1tHZAyQ+nQGjC6EA109+9VLyAQC+fY0BvIxlAtiDcP\u002fPiF0DOzaNAtkuLwKyaDb8ji3BAdYbpQE8VtECd1cE+fgesQAW1pb57q3FA06YEQGgjqEDJbuJAy1gDQcfbG0H9YKtA02XuP8oEqEAB8ZBAu8XtQA=="},"y":{"dtype":"f4","bdata":"8W9wQbvfRkGQ789AlxVxQP5XXUEhs4dBQU4kvjufKEGhmJFB0pk2QcvMhkHb0odAkVagQN7db0HPz3K8WryiQD56B0EhUSNB9rLHQD+AOEGf8YhBDsRyQaHXDEF1KINBYv+PQX3YS0E1u2dBRHaOQWQvebww8jlBG9PzQOXuSkEetDdBY0U\u002fQcvw1UDcA1xB7kFOQfLfvUCReE9B5Oj9QLfL9kBWYodAWkiMQXnHf0EAFvBAaeGIQXXHMEH3EL9AukZYQYtsrT+++WlBq0SrPmjGor8MqwxB0ZR1QStlOUHoAwNBaOFBQM0OpEC4s9xAZEwGQWUt20BAqURBZ0QcQSoog0EPDU1ByRpzQQLEhkHBQrk+aiJlQQ=="},"type ...

# %% [markdown]
# Con perplexity 25, notiamo alcuni cluster distinti, ma la forma generale è più compatta e meno strutturata rispetto alla PCA.
#
# Osserviamo in particolare in basso a sinistra un cluster di emoji azzurre (**sorpresa**), appena più a destra un cluster molto sovrapposto di emoji rosse (**rabbia**) e poi un gruppo di emoji blu in basso a destra (**tristezza**) [_quasi tutte le emoji qui hanno la lacrimuccia_].
#
# Le emoji gialle (**gioia**) sono più sparse, ma tendono a raggrupparsi verso l'alto a destra.

# %%
from Fase1.pca_utils import perform_tsne_analysis 

hybrid_features = ALL_EMOTIONS

tsne_data = perform_tsne_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all, 
    perplexity=30,  # o 15, 25, 40 ...
    scale=True      # t-SNE funziona meglio con dati scalati
)

fig_tsne = plot_pca_emotions(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE: Clustering non-lineare delle Emoji (10 Feature)",
    plot_loadings=False # Non ha senso vettori in t-SNE
)

fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id
+FvAh9pIwKdF4MAl\u002fsfAGXzavyhIlsCJttnAgcePwNnWusDrgHvAEm0ewFJe8cDDP5w+0wl2wDvK179\u002fLY7AO+NZwCSVaMBwmbnARpq3wL5TX8DYVqPAxYaawKbW+b+JyJPAkxChwPhZjr30zNS\u002feXUcwCMVVcBNGa7AnxCEwOJ0iMA+l7PA\u002f8\u002fYwHtQi8B1tUm\u002f2Hd1wF1N+L8mVcu\u002fT4jEwIp7ssCybXnACtmuwK4FosCEID7AX4HowMFcqD9o\u002f+\u002fAbgYrwGSFNb+VYwjA+M2vwGICfMC ...

# %% [markdown]
# In questo grafico t-SNE basato solo sulle emozioni discrete, vediamo i puniti meno compatti e più sparsi rispetto alla PCA, ma sono sempre evidenti dei cluster.

# %%
from Fase1.pca_utils import perform_tsne_analysis # Importa la nuova funzione

hybrid_features = VAD_FEATURES

tsne_data = perform_tsne_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all, 
    perplexity=30,  # o 15, 25, 40 ...
    scale=True      # t-SNE funziona meglio con dati scalati
)

fig_tsne = plot_pca_emotions(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE: Clustering non-lineare delle Emoji (3 VAD)",
    plot_loadings=False # Non ha senso vettori in t-SNE
)

fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="d7171c41-04ad-4257-a3f2-277a3fbde80c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7171c41-04ad-4257-a3f2-277a3fbde80c")) {                    Plotly.newPlot(                        "d7171c41-04ad-4257-a3f2-277a3fbde80c",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f4","bdata":"m6puwY8WwMD9XATBQJBOwau1+L9EY8\u002fA\u002fcKwv\u002f2JqMDE+BjBA9Ckv7AD4cCjx+nACwkCweWqRMGKOAPBHQ8RwNDcQMHhCzjB3DpkwYa04MCysn3BL9t6wecYYsB64BPBJKlEwQdWfcHOF4jBi73+wEYlncAcpF7BCZlXwc7ZMMFhfPjA0scPwVHgZsHlUknB1eW2wPgWgcCP9ijBaGsSwY5tgcE3TALBCiGMwMUDacEw2YK\u002fDdUGwW9MssD3ZNbAHyPswM3mnz\u002fpNYnBkSDCv2A1HT+suWjAeRB0wfmqgMEgo1g+QK5uwPCvhMC8zlPBYs\u002fuwNoVjcGdk3LBgl2AwIKehsFLqtrAMTxXwWO91sB3IbnA+EiIwQ=="},"y":{"dtype":"f4","bdata":"kk8PwfF2MsEfEmPAnM2UwJ1IL8GYJjzBld82wFwe2sA0ZBPBOWCjwA\u002fDicA7dg4\\u002fBYFsqwevBHMEHMGbABIbDwA=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","marker":{"color":"#FDD835","line":{"color":"white","width":1.5},"opacity":0.8,"size":12},"mode":"markers","name":"gioia","showlegend":true,"x":{"dtype":"f4","bdata":"m6puwY8WwMD9XATBQJBOwau1+L9EY8\u002fA\u002fcKwv\u002f2JqMDE+BjBA9Ckv7AD4cCjx+nACwkCweWqRMGKOAPBHQ8RwNDcQMHhCzjB3DpkwYa04MCysn3BL9t6wecYYsB64BPBJKlEwQdWfcHOF4jBi73+wEYlncAcpF7BCZlXwc7ZMMFhfPjA0scPwVHgZsHlUknB1eW2wPgWgcCP9ijBaGsSwY5tgcE3TALBCiGMwMUDacEw2YK\u002fDdUGwW9MssD3ZNbAHyPswM3mnz\u002fpNYnBkSDCv2A1HT+suWjAeRB0wfmqgMEgo1g+QK5uwPCvhMC8zlPBYs\u002fuwNoVjcGdk3LBgl2AwIKehsFLqtrAMTxXwWO91sB3IbnA+EiIwQ=="},"y":{"dtype":"f4","bdata":"kk8PwfF2MsEfEmPAnM2UwJ1IL8GYJjzBld82wFwe2sA0ZBPBOWCjwA\u002fDicA7dg4\\u002fBYFsqwevBHMEH ...

# %% [markdown]
# Con t-SNE basato solo sulle dimensioni VAD, vediamo cluster meno popolati e più sparsi, ma ancora una volta, quasi tutte le emoji rappresentati la **gioia** tendono a separarsi da tutte le altre.

# %% [markdown]
# ### TruncatedSVD

# %%
from Fase1.pca_utils import perform_svd_analysis

hybrid_features = ALL_EMOTIONS + VAD_FEATURES

svd_data = perform_svd_analysis(    # SVD non scala i dati, rispecchierà intensità grazza
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all
)

fig_svd = plot_pca_emotions(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD: Fase1 Emoji (13 Feature)",
    plot_loadings=True, # le etichette emozioni/dimensioni
    feature_names=hybrid_features
)

fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="d92ae692-08ba-4338-b3e2-f9e3d34e0721" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d92ae692-08ba-4338-b3e2-f9e3d34e0721")) {                    Plotly.newPlot(                        "d92ae692-08ba-4338-b3e2-f9e3d34e0721",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f8","bdata":"MfjLmZLYJ0AA+4NnJgEmQJw6cv+oDiRAihI5ER75JEDos6W4J6QkQI3j2Rd7piZAmGTWkNBOIkDJZAaUlaAkQL5FkNnscCZAA3\u002fA+3O6IkC2pgV7mjskQBqPeKrtAiRAKEC62IeoJEBesulEPPQmQBRAZAi1rCRAE5yAosWJIkCpEUWztUskQLxfiJyEKyRAonXrIpcgKECLRAKczcQkQB\u002f1AGLbzClAk6UpIlzlJ0CL3wu6LzIjQA4V4B2vYCZAQmV\\u002fkgQMZfHJ3CWCNAYTmmZvd2J0BniwUJO1InQBDDHSQD0yFAMnC2hujzIUAt\u002fUzKfbcjQGbjsioG2iZAlRNqTLhOJEDIgark7psnQI6KmhUbhSZA+a\u002fWUsWGJUCx\u002fqWX2EwsQIktuO53ZSZA00XsFls6KUDG0EbVqNglQExJDfbQXSNAeFL6nlbbJ0A="},"y":{"dtype":"f8","bdata":"5OvsL6wj6L8pYJPwlHv3vyCOsXaHANa\u002frYi0a89E0z8ENt95DqvVvxoBsiyeivm\u002fRj1uLWnazb\u002fPYEWQdHcBwM6H2FUdMPy\u002fDTDfYm2ACMDQdvVGk2LuvzpKMpNC6vm\u002fNKmQKwea579iQViogVT2v8yG+T\u002fI7OW\u002f9JWMNfFm+r\u002fLFLw2EWWKP76YSOxA3tC\u002fcHjj+nXm8b991hENwvH4v6susSWLaOq\u002fz8ZHa7yF8L8Ru8cKf9Xvv1J2nxUlvwPAtuncKUhqAMA9vn3ZHu3Zv2oWuzPS4M+\u002fdB0Dok3LAsAfw9cllCTjv0WYh4N7\u002f8y\u002fabODCjUW07865nqfOSj8vwtNCluXN\u002fa\u002fc5tddgXHAcC3Y\u002fvlyOm5vxcE65oVEvC\u002f5PuONUQP\u002fL+WsRzL6Fnnv0jZ5YMBjPu\u002fKYZ2j95h6r\u002f9xE3nrPWwvx8Vr\u002fpHUAHAYBcgoByi\u002fr9Oda6Qph\u002fvvx1Hg6OSZ\u002fy\u002f0GVU2muCBsAJmerVI6T1v+BzovRPL\u002fS\u002fls8C8msJ+b9b7kNLddKhPxUZOXsmzuC\u002fojqOH9Fl+b8hy+oQOxvZv3eF+\u002f1cmtW\u002fiAS+5dyB4L+hsB3b30vyvyTh3c+DP+e\u002f0k9EN8WP47\u002fAcNAlulb2v6tTrZIev\u002fG\u002fqwFD\u002fjMR6r+yccoxwmrCP10Bpa5qSOi\u002f113H0ZAj4j9xF0wnyhnvv7Ycy3TqXf2\u002fGbJzDlVNAMBPmfq7S1T+v\u002fYSx8HZ6u+\u002f7tLKc9q7zb8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","marker":{"color":"#FDD835","line":{"color":"white"," ...

# %% [markdown]
# In questa visualizzazione con TruncatedSVD, le etichette delle emozioni tendono a raggrupparsi tra loro.
#
# Nel punto con PC1 ≈ 0, PC2 ≈ 0, troviamo **sorpresa** e **neutrale**. Invece, nel punto PC1 ≈ 0, PC2 ≈ 0.4 troviamo **tristezza**, **rabbia**, **paura** e **disgusto**, che sono tutte emozioni negative. Mentre in PC1 ≈ 0 e PC2 ≈ [0.2, PC2 ≈ 0.6] troviamo **gioia**, **fiducia** e **amore**, che sono tutte emozioni positive.
#
# Per quanto riguarda le etichette VAD sono distribuite in modo più o meno euistante lungo l'asse verticale, con **attivazione** in alto, **dominanza** al centro e **valenza** in basso.
#
# Le emoji sono distanti dalle etichette per le scale diverse, ma si distribuiscono in modo simile alla PCA, con le emoji di gioia separate da quelle negative, e le emoji di sorpresa più vicine al centro.

# %%
from Fase1.pca_utils import perform_svd_analysis

hybrid_features = ALL_EMOTIONS

svd_data = perform_svd_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all
)

fig_svd = plot_pca_emotions(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD: Fase1 Emoji (10 Feature)",
    plot_loadings=True, # le etichette emozioni/dimensioni
    feature_names=hybrid_features
)

fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="ed665bcb-429c-4232-8f8b-b9723ef57ad8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ed665bcb-429c-4232-8f8b-b9723ef57ad8")) {                    Plotly.newPlot(                        "ed665bcb-429c-4232-8f8b-b9723ef57ad8",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],
="},"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u00 ...

# %% [markdown]
# In questa visualizzazione con TruncatedSVD basata solo sulle emozioni discrete, vediamo che le etichette delle emozioni si distribuiscono in modo simile alla PCA, con **gioia** che crea sempre un gruppo abbastanza separato, e le emozioni negative che tendono a raggrupparsi insieme.

# %%
from Fase1.pca_utils import perform_svd_analysis

hybrid_features = VAD_FEATURES

svd_data = perform_svd_analysis(
    df=df_only_emojis, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all
)

fig_svd = plot_pca_emotions(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD: Fase1 Emoji (3 VAD)",
    plot_loadings=True, # le etichette emozioni/dimensioni
    feature_names=hybrid_features
)

fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="380bf021-51ee-4793-922a-bb7a9f4ac761" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("380bf021-51ee-4793-922a-bb7a9f4ac761")) {                    Plotly.newPlot(                        "380bf021-51ee-4793-922a-bb7a9f4ac761",                        [{"hovertemplate":"\u003cb\u003egioia\u003c\u002fb\u003e\u003cbr\u003ePC1: %{x:.2f}\u003cbr\u003ePC2: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gioia","mode":"text","showlegend":false,"text":["\u263a","\u2665\ufe0f","\u270c","\u2714","\u2728","\u2764","\ud83c\udf1a","\ud83c\udf1d","\ud83c\udf39","\ud83c\udf3b","\ud83c\udf40","\ud83c\udf4c","\ud83c\udf51","\ud83c\udf89","\ud83d\udc45","\ud83d\udc4a","\ud83d\udc4c","\ud83d\udc4d","\ud83d\udc4f","\ud83d\udc83","\ud83d\udc96","\ud83d\udc97","\ud83d\udc99","\ud83d\udc9a","\ud83d\udc9b","\ud83d\udc9c","\ud83d\udc9d","\ud83d\udc9e","\ud83d\udca9","\ud83d\udd1d","\ud83d\udd25","\ud83d\udd7a","\ud83d\ude00","\ud83d\ude01","\ud83d\ude02","\ud83d\ude03","\ud83d\ude04","\ud83d\ude06","\ud83d\ude07","\ud83d\ude09","\ud83d\ude0a","\ud83d\ude0b","\ud83d\ude0d","\ud83d\ude0e","\ud83d\ude17","\ud83d\ude18","\ud83d\ude19","\ud83d\ude1a","\ud83d\ude1b","\ud83d\ude1c","\ud83d\ude1d","\ud83d\ude34","\ud83d\ude48","\ud83d\ude4b","\ud83d\ude4b\u200d\u2640\ufe0f","\ud83e\udd0d","\ud83e\udd0e","\ud83e\udd11","\ud83e\udd13","\ud83e\udd17","\ud83e\udd19\ud83c\udffb","\ud83e\udd23","\ud83e\udd2d","\ud83e\udd42","\ud83e\udd47","\ud83e\udd70","\ud83e\udd79","\ud83e\udde1","\ud83e\udef0","\ud83e\udef6"],"textfont":{"size":18},"textposition":"middle center","x":{"dtype":"f8","bdata":"dH0ht1mwJ0BC4EjgpNwlQCgy3mql\u002fyNAqK+ox4j4JECoHfSY1nckQLIMY26BcCZAc4qkIM9OIkDSXU4qdIAkQNuRF2ywNiZA1eIz+DeXIkAqj4BAQAgkQEiP+NDaAyRAacpWJdGfJED53HO3m8gmQKRRKyr0niRAx0sHo9mHIkA33bMdPjYkQJ6u5\u002fuwCiRA9R+P2mwUKECNoZORUaYkQJO\u002fhU8MmSlAPNvoila9J0A4m\u002fnipRsjQKp9+xB1OiZAqMdmlIciKEBiCahBmr8mQHoW4q\u002fXwCZA1gfZdCqoJkD7Rvu