# %% [markdown]
# # Visualizzasione delle parole del lessico ELIta con metodi distribuzionali
# In questo notebook, eseguiamo un'analisi delle parole del lessico ELIta utilizzando tecniche di riduzione della dimensionalità come PCA, t-SNE e TruncatedSVD. L'obiettivo è visualizzare la distribuzione delle emozioni associate alle parole presenti nel dataset ELIta.
#
# Seguiremo gli stessi passaggi del notebook di analisi delle emoji.

# %% [markdown]
# ## Separazione dei Dati (Emoji vs Parole)

# %%
import pandas as pd
import emoji
import plotly.io as pio

pio.renderers.default = "notebook_connected"

pivotedData = pd.read_csv("ELIta_INTENSITY_Matrix.csv", index_col=0)

def is_likely_emoji(text):
    return emoji.emoji_count(str(text)) > 0

pivotedData['is_emoji'] = [is_likely_emoji(x) for x in pivotedData.index]

df_only_emojis = pivotedData[pivotedData['is_emoji'] == True].copy()
df_only_words = pivotedData[pivotedData['is_emoji'] == False].copy()

print(f"Totale elementi: {len(pivotedData)}")
print(f"Numero di Emoji trovate: {len(df_only_emojis)}")
print(f"Numero di Parole testuali: {len(df_only_words)}")
# Out:
# Totale elementi: 6905
# Numero di Emoji trovate: 186
# Numero di Parole testuali: 6719

# %%
df_only_emojis.head()
# Out:
#         amore  aspettativa  attivazione  disgusto  dominanza  fiducia  gioia  \
# parola
# ‼        0.35         0.17         6.67      0.04       5.17     0.00   0.71
# ⁉        0.11         0.21         7.67      0.04       5.50     0.04   0.17
# ☠        0.15         0.04         6.00      0.46       5.50     0.12   0.17
# ☹        0.02         0.12         5.83      0.08       3.50     0.04   0.00
# ☺        0.73         0.50         6.17      0.00       7.00     0.54   0.92
#
#         neutrale  paura  rabbia  sorpresa  tristezza  valenza  is_emoji
# parola
# ‼            0.0   0.17    0.67      0.83       0.12     5.00      True
# ⁉            0.0   0.29    0.17      0.71       0.08     4.33      True
# ☠            0.0   0.67    0.54      0.17       0.58     3.83      True
# ☹            0.0   0.21    0.17      0.04       1.00     2.67      True
# ☺            0.0   0.00    0.00      0.62       0.00     7.33      True

# %%
df_only_words.head()
# Out:
#               amore  aspettativa  attivazione  disgusto  dominanza  fiducia  \
# parola
# ????           0.08         0.17         7.00      0.17       4.33     0.04
# a_caso         0.04         0.21         5.00      0.08       3.00     0.04
# a_malincuore   0.00         0.12         5.50      0.21       3.67     0.00
# a_scanso_di    0.21         0.58         5.33      0.04       4.67     0.25
# abbagliante    0.32         0.62         7.00      0.00       6.50     0.17
#
#               gioia  neutrale  paura  rabbia  sorpresa  tristezza  valenza  \
# parola
# ????           0.12       0.0   0.17    0.42      0.79       0.42     5.17
# a_caso         0.04       0.0   0.54    0.29      0.83       0.21     4.33
# a_malincuore   0.00       0.0   0.21    0.21      0.04       0.83     3.33
# a_scanso_di    0.17       0.0   0.17    0.42      0.21       0.25     5.00
# abbagliante    0.46       0.0   0.12    0.12      0.71       0.04     6.67
#
#               is_emoji
# parola
# ...

# %% [markdown]
# ## Visualizzazione delle Parole (PCA)

# %%
import pandas as pd
from Fase1.emotion_config import EMOTION_COLORS, BASIC_EMOTIONS, ALL_EMOTIONS, VAD_FEATURES
from Fase1.pca_utils import perform_pca_analysis, perform_tsne_analysis, perform_svd_analysis
from Fase1.visualizer import plot_pca_single, plot_pca_3d

# Calcolo emozioni dominanti per le PAROLE (non emoji)
dominant_basic_words = df_only_words[BASIC_EMOTIONS].fillna(0).idxmax(axis=1)   # Plutchik
dominant_all_words = df_only_words[ALL_EMOTIONS].fillna(0).idxmax(axis=1)       # Plutchik + Amore + Neutrale

# %% [markdown]
# ### Visualizzazione PCA per le 8 Emozioni di Base

# %%
pca_basic = perform_pca_analysis(df_only_words, BASIC_EMOTIONS, dominant_basic_words)

fig1 = plot_pca_single(
    pca_data=pca_basic,
    colors_dict={k: v for k, v in EMOTION_COLORS.items() if k in BASIC_EMOTIONS},
    title="PCA Parole: Distribuzione 8 Emozioni Base"
)
fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Eseguendo la PCA solo sulle 8 emozioni di base, osserviamo una struttura radiale, simile a un ventaglio.
#
# Le parole con una singola emozione forte si dovrebbero trovare all'estremità del ventaglio, mentre quelle con emozioni miste si concentrano al centro.
#
# Le parole identificate da emozioni negative tendono a trovarsi a sinistra, mentre quelle positive a destra.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 10 Emozioni (8 di base + 2 extra)

# %%
pca_all = perform_pca_analysis(df_only_words, ALL_EMOTIONS, dominant_all_words)

fig2 = plot_pca_single(
    pca_data=pca_all,
    colors_dict=EMOTION_COLORS,
    title="PCA Parole: Spazio a 10 Emozioni (+ Amore e Neutrale)"
)
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# L'aggiunta di Amore e Neutrale non stravolge la struttura generale, ma il ventaglio si sbilancia leggermente. La parte positiva si espande un po' di più, coerentemente con il fatto che **amore** rafforza la direzione già esistente tra gioia e fiducia senza  introdurre una nuova dimensione emotiva.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 3 Dimensioni VAD, senza standirdizzazione
# Senza standardizzazione, per vedere l'effetto delle scale originali (1-9).

# %%
pca_vad = perform_pca_analysis(df_only_words, VAD_FEATURES, dominant_all_words, scale=False)

fig3 = plot_pca_single(
    pca_data=pca_vad,
    colors_dict=EMOTION_COLORS,
    title="PCA Parole: VAD (Scale Originali)",
    plot_loadings=True,
    feature_names=VAD_FEATURES
)
fig3.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# La PCA sulle dimensioni VAD mostra una distribuzione più compatta, con le parole che tendono a raggrupparsi verso il centro. Sparisce la struttura a ventaglio vista con le emozioni discrete, ora i punti si distribuiscono in una nuvola orizzontale.
#
# PC1 sembra essere guidata da Valenza e Dominanza, mentre PC2 principalmente da Attivazione.
#
# Le parole positive e dominanti stanno a destra, quelle negative a sinistra. Mentre le parole ad alta energia in alto, calme in basso.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA per le 3 Dimensioni VAD, con standirdizzazione
# Con standardizzazione, per portare le scale 1-9 su una scala comparabile (z-score).

# %%
pca_vad_scaled = perform_pca_analysis(df_only_words, VAD_FEATURES, dominant_all_words, scale=True)

fig4 = plot_pca_single(
    pca_data=pca_vad_scaled,
    colors_dict=EMOTION_COLORS,
    title="PCA Parole: VAD Standardizzata (Z-Score)",
    plot_loadings=True,
    feature_names=VAD_FEATURES
)
fig4.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Applicando lo z-score, la distribuzione visivamente non sembra cambiare drasticamente, ma ora le componenti sono più bilanciate in termini di _varianza spiegata_ ( quanto dell'informazione originale sopravvive alla riduzione dimensionale, proiettando da 13D a 2D).
#
# PC1 (ancora guidata da Valenza e Dominanza) è scesa, mentre PC2 (Attivazione) è salita.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizzazione PCA VAD 3D

# %%
pca_vad_3d = perform_pca_analysis(
    df=df_only_words, 
    features_columns=VAD_FEATURES, 
    dominant_emotions=dominant_all_words, 
    scale=True,        
    n_components=3     
)

fig_3d = plot_pca_3d(
    pca_data=pca_vad_3d,
    colors_dict=EMOTION_COLORS,
    title="Spazio Emotivo 3D Parole (VAD)"
)

fig_3d.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Le parole si distribuiscono in una nuvola tridimensionale abbastanza compatta, dove emergono cluster di parole con stessa emozione dominante.
#
# Le parole che più si scostano dal centro sono quelle con emozioni più forti.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pca_obj = pca_vad_3d['pca_object']
components = pca_obj.components_

loadings_df = pd.DataFrame(
    components,
    columns=['Valenza', 'Attivazione', 'Dominanza'],
    index=['PC1', 'PC2', 'PC3']
)

plt.figure(figsize=(8, 4))
sns.heatmap(loadings_df, annot=True, cmap='RdBu', center=0, fmt='.2f', vmin=-1, vmax=1)
plt.title("Di cosa sono fatti gli assi PC? (Correlazione Features-Componenti)")
plt.show()

print(loadings_df)
# Out:
#       Valenza  Attivazione  Dominanza
# PC1  0.693808    -0.244679   0.677320
# PC2  0.101650     0.964370   0.244249
# PC3  0.712950     0.100612  -0.693959

# %% [markdown]
# Dalla matrice di loadings, vediamo che:
# - PC1 è fortemente correlata con Valenza e Dominanza, quindi rappresenta una dimensione di "Positività e Controllo" delle parole.
# - PC2 è fortemente correlata con Attivazione, rappresentando una dimensione di "Energia" o "Intensità" emotiva.
# - PC3 mostra una associazione negativa con Dominanza e positiva con Valenza, ma è meno chiara da interpretare. Potrebbe rappresentare una dimensione più complessa che differenzia parole positive ma non dominanti da parole negative ma dominanti.

# %% [markdown]
# ### Visualizzazione PCA per tutte le 13 Feature

# %%
hybrid_features = ALL_EMOTIONS + VAD_FEATURES

pca_hybrid = perform_pca_analysis(
    df=df_only_words, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all_words, 
    scale=True
)

fig5 = plot_pca_single(
    pca_data=pca_hybrid,
    colors_dict=EMOTION_COLORS,
    title="PCA Ibrida Parole: Emozioni + VAD (13 feature)",
    plot_loadings=True,
    feature_names=hybrid_features 
)
fig5.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Torna a emergere una struttura a ventaglio, ma più sfumata rispetto alla PCA con solo le emozioni discrete.
#
# Le etichette **neutrale** e **attivazione** si posizionano più vicine al centro, indicando che molte parole hanno valori moderati su queste dimensioni. Le parole più estreme si trovano verso i bordi del ventaglio, con quelle positive e dominanti a destra, e quelle negative a sinistra.

# %% [markdown]
# ## t-SNE

# %%
tsne_data = perform_tsne_analysis(
    df=df_only_words, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all_words, 
    perplexity=50, # Per le parole, potrebbe serivere una perplexity più alta rispetto alle emoji, più componenti
    scale=True
)

fig_tsne = plot_pca_single(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE Parole: Clustering Non-Lineare (13 Feature)",
    plot_loadings=False
)
fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# La visualizzazione t-SNE con tutte le 13 feature mostra cluster più nettamente separati rispetto alla PCA: le emozioni tendono a raggrupparsi in aree distinte, con meno sovrapposizione. Tuttavia, a differenza della PCA non si può dedurre dal grafico quanto due emozioni siano "vicine" in termini assoluti.
#
# Analizzando i cluster con gli strumenti di Plotly, si possono identificare gruppi di parole con emozioni simili semanticamente coerenti, anche se alcuni cluster risultano più misti di altri.

# %%
tsne_data = perform_tsne_analysis(
    df=df_only_words, 
    features_columns=ALL_EMOTIONS, 
    dominant_emotions=dominant_all_words, 
    perplexity=50,
    scale=True
)

fig_tsne = plot_pca_single(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE Parole: Clustering Non-Lineare (10 Feature)",
    plot_loadings=False
)
fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Nella t-SNE con solo le 10 emozioni discrete, i cluster risultano ancora più netti e distinti. Le emozioni negative si raggruppano chiaramente in un'area, mentre quelle positive in un'altra.

# %%
tsne_data = perform_tsne_analysis(
    df=df_only_words, 
    features_columns=VAD_FEATURES, 
    dominant_emotions=dominant_all_words, 
    perplexity=50,
    scale=True
)

fig_tsne = plot_pca_single(
    pca_data=tsne_data,
    colors_dict=EMOTION_COLORS,
    title="t-SNE Parole: Clustering Non-Lineare (3 VAD)",
    plot_loadings=False
)
fig_tsne.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Con le sole 3 dimensioni VAD, t-SNE produce una struttura più frammentata: i cluster sono più numerosi e piccoli.
#
# La separazione positivo/negativo rimane visibile. Questo conferma che le VAD catturano la valenza generale ma non le sfumature emotive che emergono invece con le 8 emozioni discrete.

# %% [markdown]
# ## TruncatedSVD

# %%
svd_data = perform_svd_analysis(
    df=df_only_words, 
    features_columns=hybrid_features, 
    dominant_emotions=dominant_all_words
)

fig_svd = plot_pca_single(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD Parole: Intensità Emotiva (13 dimensioni)",
    plot_loadings=True,
    feature_names=hybrid_features
)
fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# La visualizzazione con TruncatedSVD su 13 features mostra una struttura simile alla PCA, ma con una distribuzione più compatta dei punti.
#
# Ciò dovrebbe essere dovuto al fatto che SVD non standardizza i dati, quindi le parole con valori più alti nelle feature originali (le VAD) tendono a dominare la proiezione, portando a una maggiore concentrazione dei punti verso il centro del grafico.
#
# Le parole che quindi si discostano maggiormente dal centro sono quelle con emozioni più forti, mentre quelle più vicine al centro hanno valori più moderati o bilanciati tra le emozioni.
#
# Per le etichette di emozioni/dimensioni, le osservazioni sono uguali a quelle fatte nel notebook delle emoji.

# %%
svd_data = perform_svd_analysis(
    df=df_only_words, 
    features_columns=ALL_EMOTIONS,
    dominant_emotions=dominant_all_words
)

fig_svd = plot_pca_single(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD Parole: Intensità Emotiva (10 dimensioni)",
    plot_loadings=True,
    feature_names=ALL_EMOTIONS
)
fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# La visualizzazione con TruncatedSVD sulle 10 emozioni discrete mostra ancora una volta una struttura a ventaglio. Le parole con emozioni più forti si trovano verso i bordi del ventaglio, mentre quelle con emozioni più miste o moderate si concentrano al centro (indicate anche dall'etichetta **neutrale**).
#
# Le etichette delle emozioni le emozioni negative si trovano in alto, mentre quelle positive in basso, sempre ben separate tra loro.

# %%
svd_data = perform_svd_analysis(
    df=df_only_words, 
    features_columns=VAD_FEATURES, 
    dominant_emotions=dominant_all_words
)

fig_svd = plot_pca_single(
    pca_data=svd_data,
    colors_dict=EMOTION_COLORS,
    title="TruncatedSVD Parole: Intensità Emotiva (3 dimensioni)",
    plot_loadings=True,
    feature_names=VAD_FEATURES
)
fig_svd.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# La visualizzazione con TruncatedSVD sulle 3 dimensioni VAD mostra una distribuzione compatta.
#
# I due assi PC1 e PC2 hanno varianza quasi equivalente, nessuna delle dimensioni VAD ha una direzione dominante netta.
